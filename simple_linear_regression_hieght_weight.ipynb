# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./Heights and weights.csv')

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
for i in df.columns:
    sns.histplot(x = df[i])
    plt.show()

# %%
df.shape
# Out:
# (15, 2)

# %%
for i in df.columns:
    sns.boxplot(y = df[i])
    plt.show()

# %%
height = df[['Height']]
weight = df[['Weight']]

# %%
height
# Out:
#     Height
# 0     1.47
# 1     1.50
# 2     1.52
# 3     1.55
# 4     1.57
# 5     1.60
# 6     1.63
# 7     1.65
# 8     1.68
# 9     1.70
# 10    1.73
# 11    1.75
# 12    1.78
# 13    1.80
# 14    1.83

# %%
weight
# Out:
#     Weight
# 0    52.21
# 1    53.12
# 2    54.48
# 3    55.84
# 4    57.20
# 5    58.57
# 6    59.93
# 7    61.29
# 8    63.11
# 9    64.47
# 10   66.28
# 11   68.10
# 12   69.92
# 13   72.19
# 14   74.46

# %%
x_train, x_test, y_train, y_test = train_test_split(height,weight, test_size=0.2)

# %%
x_train.shape
# Out:
# (12, 1)

# %%
x_test
# Out:
#     Height
# 10    1.73
# 11    1.75
# 14    1.83

# %%
reg = LinearRegression()
reg = reg.fit(x_train,y_train)

# %%
pred_weight
# Out:
# LinearRegression()

# %%
pred_weight = reg.predict(x_test)

# %%
pred_weight
# Out:
# array([[66.69655932],
#        [67.88783736],
#        [72.65294954]])

# %%
df1=pd.DataFrame(zip(y_test.Weight,pred_weight), columns=['actual','predicted'])

# %%
y_test.Weight
# Out:
# 10    66.28
# 11    68.10
# 14    74.46
# Name: Weight, dtype: float64

# %%
df1
# Out:
#    actual            predicted
# 0   66.28  [66.69655932089202]
# 1   68.10   [67.8878373644142]
# 2   74.46  [72.65294953850301]

# %%
sns.regplot(x=height,y=weight)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
reg.coef_
# Out:
# array([[59.56390218]])

# %%
reg.intercept_
# Out:
# array([-36.34899144])
